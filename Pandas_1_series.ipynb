# %% [markdown]
# <a href="https://colab.research.google.com/github/vrajsavliya/ml_learning/blob/main/Pandas_1_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %% [markdown]
# best for manuplating the whole dataset.
#
# *.. Pandas have two objects 1)series
# 2)dataframe

# %%
import numpy as np
import pandas as pd # is used to import pandas

# %% [markdown]
# ## Series from lists
#
# There are different ways to build the series

# %%
# using arrays or can say python list
country =['India','pak','USA','Nepal']
pd.Series(country)
# Out:
# 0    India
# 1      pak
# 2      USA
# 3    Nepal
# dtype: object

# %%
#Integer type series
runs = [13,12,3,4,5,62,4,533,5]
pd.Series(runs,dtype=np.int32)
# Out:
# 0     13
# 1     12
# 2      3
# 3      4
# 4      5
# 5     62
# 6      4
# 7    533
# 8      5
# dtype: int32

# %%
# Custom indexing and integer list

marks = [80,99,75,89]
subjects = ['english','math','hindi','SS']

pd.Series(marks,index=subjects) #Custom index bana ne ke liyee best hai yee
# Out:
# english    80
# math       99
# hindi      75
# SS         89
# dtype: int64

# %%
# setting a name
pd.Series(marks,index=subjects,name='Vraj svliya ke marks')
# Out:
# english    80
# math       99
# hindi      75
# SS         89
# Name: Vraj svliya ke marks, dtype: int64

# %% [markdown]
# ## Series from dict

# %%
marks = {
    'maths' : 99,
    'English' : 89,
    'Hindi' : 79,
    'Science' : 86
}

marks_series = pd.Series(marks,name = 'Vraj Savliya ke Marks')
marks_series
# Out:
# maths      99
# English    89
# Hindi      79
# Science    86
# Name: Vraj Savliya ke Marks, dtype: int64

# %% [markdown]
# ## Series Attributes

# %%
#size

#tell about the number of items or can say tell about the size
marks_series.size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1763/1113884601.py in <cell line: 0>()
#       2
#       3 #tell about the number of items or can say tell about the size
# ----> 4 marks_series.size
#
# NameError: name 'marks_series' is not defined

# %%
#dtype

marks_series.dtype
# Out:
# dtype('int64')

# %%
# name

marks_series.name
# Out:
# 'Vraj Savliya ke Marks'

# %%
# is_uniuqe

marks_series.is_unique
# Out:
# True

# %%
#index

marks_series.index
# Out:
# Index(['maths', 'English', 'Hindi', 'Science'], dtype='object')

# %%
# values

type(marks_series.values)
marks_series.values
# Out:
# array([99, 89, 79, 86])

# %% [markdown]
# ## Series using read_csv

# %%
# with one col
#jub bhi hum pd.read_csv krr te hai na to pandas ausko dataframe ke format me store krr te hai aur na ki series me

subs = pd.read_csv('/content/subs.csv')
subs = subs.squeeze("columns")
type(subs)
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1763/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# with 2 cols

kohli = pd.read_csv('/content/kohli_ipl.csv',index_col = 'match_no')
kohli = kohli.squeeze('columns')

kohli
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col = 'movie')
movies = movies.squeeze('columns')
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ## Series methods

# %%
# head and tail
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
subs.tail()
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
# sample
subs.sample(5)
# Out:
# 213    115
# 288    202
# 7       40
# 242    158
# 323    196
# Name: Subscribers gained, dtype: int64

# %%
# value_count -> movies
movies
movies.value_counts()
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values -> inplace
subs.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(396)

# %%
# sort_index -> inplace -> movies

movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ## Series Maths Methods

# %%
# count
kohli.count()
# Out:
# np.int64(215)

# %%
# sum -> product
subs.sum()
# Out:
# np.int64(49510)

# %%
# mean median mode std var

subs.mean()
subs.median()
subs.mode()
subs.std()
subs.var()
# Out:
# 3928.1585127201556

# %%
# min max
subs.max()
# Out:
# 396

# %%
# describe
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# ##Series Indexing

# %%
# integer insdexing
x = pd.Series([12,13,14,15,35,46,2,42,1])
x[1]

# agar indexing positive hai to kam karega aur agar indexing string ke format me hai to kam nhi karega
# Out:
# np.int64(13)

# %%
# negative indexing it does no work for series

# %%
 # slicing
 kohli[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
# negative slicing
kohli[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[-5:]
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
movies[5:9]
# Out:
# movie
# Soni (film)                         Geetika Vidya Ohlyan
# Fraud Saiyaan                               Arshad Warsi
# Bombairiya                                  Radhika Apte
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
# Name: lead, dtype: object

# %%
# fancy indexing
kohli[[1,2,3,4]]
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# Name: runs, dtype: int64

# %% [markdown]
# ## Editing Series

# %%
# using indexing
marks_series[1] = 100
marks_series
# Out:
# /tmp/ipykernel_1763/1523408178.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100
# maths       99
# English    100
# Hindi       79
# Science     86
# Name: Vraj Savliya ke Marks, dtype: int64

# %%
# what if an index does not exist
marks_series['sst'] = 90
marks_series
# Out:
# maths       99
# English    100
# Hindi       79
# Science     86
# sst         90
# Name: Vraj Savliya ke Marks, dtype: int64

# %% [markdown]
# ## Series with python functionality

# %%
# len/type/dir/sorted/max/min

# %%
#type conversion
list(marks_series)
dict(marks_series)
# Out:
# {'maths': np.int64(99),
#  'English': np.int64(100),
#  'Hindi': np.int64(79),
#  'Science': np.int64(86),
#  'sst': np.int64(90)}

# %%
# membership operator
'Battalion 609' in movies
# Out:
# True

# %%
# looping
#for i in movies:
  #print(i)

# upar vala aabhi value prr chal hai aur agar hume aapne custom index chaiye to

for i in movies.index:
  print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# arithmetic operator

marks_series + 100
# Out:
# maths      199
# English    200
# Hindi      179
# Science    186
# sst        190
# Name: Vraj Savliya ke Marks, dtype: int64

# %%
# Relational Operators

subs > 100
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 360     True
# 361     True
# 362     True
# 363     True
# 364     True
# Name: Subscribers gained, Length: 365, dtype: bool

# %% [markdown]
# ## Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli
kohli[kohli >= 50].size
# Out:
# 50

# %%
# find the number of ducks

kohli[kohli == 0].size
# Out:
# 9

# %%
subs[subs >= 200].size
# Out:
# 59

# %%
#movies
movie_count = movies.value_counts()
movie_count[movie_count > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
subs.plot()
# Out:
# <Axes: >

# %%
num = movies.value_counts().head(20).plot(kind='bar')
